# %%
import pandas as pd

df = pd.read_csv('/content/score.csv')
display(df.head())
# Out:
#       osmid                              name  ped_distance  running_score
# 0   9965723                    Phố Tràng Tiền       0.00000             34
# 1   9978719                  Đường Ngô Gia Tự       0.00000             38
# 2  10048345  Đường cao tốc Nội Bài – Bắc Ninh       0.00000             34
# 3  10231739        Vòng xoay Cầu Chương Dương       9.71236             29
# 4  10232151             Đường Trần Quang Khải       0.00000             38

# %%
top_10_ways = df.sort_values(by='running_score', ascending=False).head(10)
display(top_10_ways)
# Out:
#            osmid                  name  ped_distance  running_score
# 757    490879004          Lê Quang Đạo           0.0             40
# 4030  1239581821       Đường Phạm Hùng           0.0             40
# 1176   602437549       Phố Chu Huy Mân           0.0             40
# 2121   709368689  Đường Khuất Duy Tiến           0.0             40
# 197    106053500     Đường Nguyễn Trãi           0.0             40
# 3490  1098003243   Đường Phạm Văn Đồng           0.0             40
# 1192   615481458   Đường Phạm Văn Đồng           0.0             40
# 4027  1239575054   Đường Phạm Văn Đồng           0.0             40
# 1643   704938983            Đường Láng           0.0             40
# 2183   709798665     Đại lộ Thăng Long           0.0             40
