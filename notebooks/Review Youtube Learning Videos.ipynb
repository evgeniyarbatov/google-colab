# %%
import pandas as pd
import re
from datetime import datetime
import sys

def analyze_video_quality(csv_file):
    """
    Analyze videos and score them based on quality indicators.
    Returns a scored and sorted DataFrame.
    """
    # Read the CSV
    df = pd.read_csv(csv_file)

    # Initialize quality score
    df['quality_score'] = 0
    df['score_breakdown'] = ''

    # 1. Title Quality (max 25 points)
    # Penalize clickbait indicators, reward descriptive titles
    def score_title(title):
        score = 15  # base score
        breakdown = []

        if pd.isna(title):
            return 0, "No title"

        title_lower = title.lower()

        # Penalize excessive punctuation/caps
        if title.count('!') > 2 or title.count('?') > 2:
            score -= 5
            breakdown.append("-5 excessive punctuation")

        # Penalize all caps words (clickbait indicator)
        caps_words = sum(1 for word in title.split() if word.isupper() and len(word) > 2)
        if caps_words > 2:
            score -= 5
            breakdown.append("-5 too many caps")

        # Reward reasonable length (40-80 chars is optimal)
        title_len = len(title)
        if 40 <= title_len <= 80:
            score += 10
            breakdown.append("+10 good length")
        elif title_len < 20:
            score -= 5
            breakdown.append("-5 too short")

        return score, '; '.join(breakdown)

    df['title_score'], df['title_notes'] = zip(*df['title'].apply(score_title))
    df['quality_score'] += df['title_score']

    # 2. Description Quality (max 25 points)
    def score_description(desc):
        score = 0
        breakdown = []

        if pd.isna(desc):
            return 0, "No description"

        desc_len = len(desc)

        # Reward substantial descriptions
        if desc_len > 200:
            score += 15
            breakdown.append("+15 detailed desc")
        elif desc_len > 100:
            score += 10
            breakdown.append("+10 decent desc")
        elif desc_len > 50:
            score += 5
            breakdown.append("+5 basic desc")

        # Check for hashtag spam
        hashtag_count = desc.count('#')
        if hashtag_count > 10:
            score -= 10
            breakdown.append("-10 hashtag spam")
        elif hashtag_count > 5:
            score -= 5
            breakdown.append("-5 many hashtags")

        # Reward informative content
        info_keywords = ['learn', 'guide', 'tutorial', 'explain', 'how to', 'tips']
        if any(keyword in desc.lower() for keyword in info_keywords):
            score += 10
            breakdown.append("+10 educational")

        return score, '; '.join(breakdown)

    df['desc_score'], df['desc_notes'] = zip(*df['description'].apply(score_description))
    df['quality_score'] += df['desc_score']

    # 3. Channel Quality (max 20 points)
    def score_channel(channel):
        score = 10  # base score
        breakdown = []

        if pd.isna(channel):
            return 0, "No channel"

        # Reward established naming patterns
        if len(channel) > 5:
            score += 10
            breakdown.append("+10 established channel")

        return score, '; '.join(breakdown)

    df['channel_score'], df['channel_notes'] = zip(*df['channelTitle'].apply(score_channel))
    df['quality_score'] += df['channel_score']

    # 4. Recency (max 15 points)
    def score_recency(publish_time):
        if pd.isna(publish_time):
            return 0, "No date"

        try:
            pub_date = pd.to_datetime(publish_time)
            now = datetime.now()
            days_old = (now - pub_date).days

            if days_old < 30:
                return 15, "+15 very recent"
            elif days_old < 90:
                return 12, "+12 recent"
            elif days_old < 180:
                return 8, "+8 somewhat recent"
            elif days_old < 365:
                return 5, "+5 within year"
            else:
                return 2, "+2 older content"
        except:
            return 0, "Invalid date"

    df['recency_score'], df['recency_notes'] = zip(*df['publishTime'].apply(score_recency))
    df['quality_score'] += df['recency_score']

    # 5. Language Consistency (max 15 points)
    def score_language(title, desc, channel):
        score = 15  # base score
        breakdown = []

        # Check if content is primarily in one language
        # This is a simple heuristic - mix of languages might indicate lower quality
        has_english = any(pd.notna(x) and bool(re.search('[a-zA-Z]', str(x)))
                         for x in [title, desc, channel])
        has_arabic = any(pd.notna(x) and bool(re.search('[\u0600-\u06FF]', str(x)))
                        for x in [title, desc, channel])
        has_other = any(pd.notna(x) and bool(re.search('[^\u0000-\u007F\u0600-\u06FF]', str(x)))
                       for x in [title, desc, channel])

        lang_count = sum([has_english, has_arabic, has_other])

        if lang_count > 1:
            score -= 5
            breakdown.append("-5 mixed languages")

        return score, '; '.join(breakdown) if breakdown else "+15 consistent"

    df['lang_score'], df['lang_notes'] = zip(*df.apply(
        lambda x: score_language(x['title'], x['description'], x['channelTitle']),
        axis=1
    ))
    df['quality_score'] += df['lang_score']

    # Combine all breakdown notes
    df['score_breakdown'] = (
        df['title_notes'] + ' | ' +
        df['desc_notes'] + ' | ' +
        df['channel_notes'] + ' | ' +
        df['recency_notes'] + ' | ' +
        df['lang_notes']
    )

    # Sort by quality score (highest first)
    df = df.sort_values('quality_score', ascending=False)

    return df

def display_results(df, top_n=10):
    """Display top N videos with their scores"""
    print(f"\n{'='*100}")
    print(f"TOP {top_n} HIGHEST QUALITY VIDEOS")
    print(f"{'='*100}\n")

    for idx, row in df.head(top_n).iterrows():
        print(f"Rank: {list(df.index).index(idx) + 1}")
        print(f"Quality Score: {row['quality_score']:.0f}/100")
        print(f"Title: {row['title'][:80]}...")
        print(f"Channel: {row['channelTitle']}")
        print(f"Published: {row['publishTime'][:10]}")
        print(f"URL: {row['url']}")
        print(f"Score Breakdown: {row['score_breakdown']}")
        print(f"{'-'*100}\n")

def save_results(df, output_file='video_analysis_results.csv'):
    """Save scored results to a new CSV"""
    # Select relevant columns
    output_cols = ['videoId', 'title', 'channelTitle', 'publishTime',
                   'url', 'searchTerm', 'quality_score', 'score_breakdown']

    df[output_cols].to_csv(output_file, index=False)
    print(f"\nResults saved to: {output_file}")

if __name__ == "__main__":
    # Usage
    csv_file = '/content/videos.csv'  # Change this to your file path

    try:
        print("Analyzing videos...")
        df_scored = analyze_video_quality(csv_file)

        # Display top 10 videos
        display_results(df_scored, top_n=100)

        # Save all results
        save_results(df_scored)

        # Display statistics
        print(f"\n{'='*100}")
        print("QUALITY DISTRIBUTION")
        print(f"{'='*100}")
        print(f"Average Score: {df_scored['quality_score'].mean():.1f}")
        print(f"Median Score: {df_scored['quality_score'].median():.1f}")
        print(f"Highest Score: {df_scored['quality_score'].max():.1f}")
        print(f"Lowest Score: {df_scored['quality_score'].min():.1f}")
        print(f"\nTotal Videos Analyzed: {len(df_scored)}")

    except FileNotFoundError:
        print(f"Error: Could not find '{csv_file}'")
        print("Please make sure the file exists in the current directory.")
    except Exception as e:
        print(f"Error: {e}")
# Out:
# Analyzing videos...
#
# ====================================================================================================
# TOP 100 HIGHEST QUALITY VIDEOS
# ====================================================================================================
#
# Rank: 1
# Quality Score: 80/100
# Title: Sunset River Reflection STEP by STEP Acrylic Painting Tutorial...
# Channel: ColorByFeliks
# Published: 2025-05-29
# URL: https://www.youtube.com/watch?v=Yqvawojuwu4
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 2
# Quality Score: 80/100
# Title: The mindset of a 3D Artist... How to not &quot;lose it&quot; ( LIVESTREAM )...
# Channel: MH Tutorials
# Published: 2021-05-05
# URL: https://www.youtube.com/watch?v=n4wwCSJWjE4
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 3
# Quality Score: 80/100
# Title: Palette knife OIL demo | 5 TIPS for finding your Art Style!...
# Channel: ZR Fine Art
# Published: 2025-01-22
# URL: https://www.youtube.com/watch?v=s-zGOVH56LM
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 4
# Quality Score: 80/100
# Title: How to find your Comic Book Art Style Pt. 1...
# Channel: RobsonINK
# Published: 2014-02-24
# URL: https://www.youtube.com/watch?v=61Jn2kf3eDA
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 5
# Quality Score: 80/100
# Title: How to Get Rid of Artist Block by Painting a Snow Globe Full of  Cardinals...
# Channel: Ginger Cook (Learn to Paint)
# Published: 2017-07-12
# URL: https://www.youtube.com/watch?v=_LM4J1tUVPE
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 6
# Quality Score: 80/100
# Title: How This 1 Trick Changed My Graffiti Forever!...
# Channel: The Artist Block
# Published: 2024-10-11
# URL: https://www.youtube.com/watch?v=ppifN2t8W80
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 7
# Quality Score: 80/100
# Title: Painting With Passion Taking Your Art To The Next Level Through Artist Statement...
# Channel: Stefan Baumann
# Published: 2015-08-17
# URL: https://www.youtube.com/watch?v=N-JyP99q2xs
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 8
# Quality Score: 80/100
# Title: How To Draw A Graffiti Piece Full Process...
# Channel: The Artist Block
# Published: 2024-08-23
# URL: https://www.youtube.com/watch?v=L8T7U7u9ivY
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 9
# Quality Score: 80/100
# Title: How to Do &amp; Practice Graffiti (Tags, Throwies, Pieces)...
# Channel: The Artist Block
# Published: 2024-09-07
# URL: https://www.youtube.com/watch?v=xX2kOBd50oU
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 10
# Quality Score: 80/100
# Title: The Artistic Evolution of Legend of Zelda...
# Channel: Stylized Station
# Published: 2021-10-20
# URL: https://www.youtube.com/watch?v=V-h1sWmgkuU
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 11
# Quality Score: 80/100
# Title: Yoga Nidra for Creative Flow {Artistic Breakthrough}...
# Channel: Ty Holgate | Empowerment Mentor
# Published: 2023-06-08
# URL: https://www.youtube.com/watch?v=e-37cY02SUA
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 12
# Quality Score: 80/100
# Title: Using Blender 3D in creating art and finding your artistic voice #ep2  #podcast...
# Channel: Jeni with Mandra
# Published: 2025-01-17
# URL: https://www.youtube.com/watch?v=zkifLI5CWgQ
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 13
# Quality Score: 80/100
# Title: an honest sketchbook tour | developing my voice as an artist...
# Channel: Orla Stevens
# Published: 2025-01-30
# URL: https://www.youtube.com/watch?v=ZdCSpcS-57Y
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 14
# Quality Score: 80/100
# Title: How to Find Your Artistic Style (FREE Workshop)...
# Channel: Milan Art Institute
# Published: 2024-04-10
# URL: https://www.youtube.com/watch?v=PiYj-vFkSsg
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 15
# Quality Score: 80/100
# Title: I Tested Ancient Ball Making Techniques!...
# Channel: Hafu Go
# Published: 2025-09-27
# URL: https://www.youtube.com/watch?v=jbVdFJAgP1Y
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 16
# Quality Score: 80/100
# Title: Review &amp; Giveaway! Watercolor Books by Sarah Simon...
# Channel: Art On the Creek
# Published: 2024-08-11
# URL: https://www.youtube.com/watch?v=Clv-c6CmDAs
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 17
# Quality Score: 80/100
# Title: Watercolor spring nest - step by step tutorial...
# Channel: Kristin Van Leuven
# Published: 2024-03-16
# URL: https://www.youtube.com/watch?v=AMavabW5wP4
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 18
# Quality Score: 80/100
# Title: REVIEW: Modern Watercolor Botanicals by Sarah Simon, The Mint Gardener...
# Channel: Art On the Creek
# Published: 2024-06-09
# URL: https://www.youtube.com/watch?v=cZyawI3KKK0
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 19
# Quality Score: 80/100
# Title: Art Journal - Experimental Journal - A Rubber Dance inspired page...
# Channel: Helen Allen
# Published: 2015-05-20
# URL: https://www.youtube.com/watch?v=EotJsHY4F-Y
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 20
# Quality Score: 80/100
# Title: Waterways with Praying Mantis, Experimental Watercolour Techniques...
# Channel: Linda Brown
# Published: 2021-10-05
# URL: https://www.youtube.com/watch?v=i5Kf9Y5mPmE
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 21
# Quality Score: 80/100
# Title: How to Create a Modern and Impressive Watercolor Zentangle...
# Channel: Hu Art Drawing
# Published: 2024-12-20
# URL: https://www.youtube.com/watch?v=rLarFqddLCI
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 22
# Quality Score: 80/100
# Title: How to paint floral compositions using the watercolor flowers you already know...
# Channel: Kristin Van Leuven
# Published: 2024-02-10
# URL: https://www.youtube.com/watch?v=c3K__0i54R0
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 23
# Quality Score: 80/100
# Title: GREYSCALE to COLOR - Digital Painting Tutorial...
# Channel: Dave Greco
# Published: 2020-01-24
# URL: https://www.youtube.com/watch?v=LeZc-uYXv3Y
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 24
# Quality Score: 80/100
# Title: Being An Artist Is Lonely - Dr. Ken Atchity...
# Channel: Film Courage
# Published: 2019-07-10
# URL: https://www.youtube.com/watch?v=mIbwNzu1ZkU
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 25
# Quality Score: 80/100
# Title: Ryan Makes DIY Giant Bubble Art! Learn Kids Experiment!...
# Channel: Ryan's World
# Published: 2024-04-01
# URL: https://www.youtube.com/watch?v=-qVSNv0cTxo
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 26
# Quality Score: 80/100
# Title: Easy DIY Art Experiments at Crayola Experience | Color Education for Children...
# Channel: The Ellie Sparkles Show - WildBrain
# Published: 2020-01-23
# URL: https://www.youtube.com/watch?v=9o6kVsH6ki0
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 27
# Quality Score: 80/100
# Title: Watercolor pine trees broken down into an easy to understand painting formula...
# Channel: Kristin Van Leuven
# Published: 2024-11-23
# URL: https://www.youtube.com/watch?v=Av7tq2HuoR8
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 28
# Quality Score: 80/100
# Title: Intuitive mark making exercise: watercolor leaves...
# Channel: Kristin Van Leuven
# Published: 2024-08-31
# URL: https://www.youtube.com/watch?v=50P2mZE_h_E
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 29
# Quality Score: 80/100
# Title: Paint a watercolor landscape with me using my landscape formula...
# Channel: Kristin Van Leuven
# Published: 2024-02-24
# URL: https://www.youtube.com/watch?v=Eyc1UhUNzNA
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 30
# Quality Score: 80/100
# Title: Intuitive mark making exercise: watercolor flowers...
# Channel: Kristin Van Leuven
# Published: 2024-09-07
# URL: https://www.youtube.com/watch?v=sqn56vSWxD4
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 31
# Quality Score: 80/100
# Title: Watercolor snowy trees using salt and painting a spontaneous snowy landscape...
# Channel: Kristin Van Leuven
# Published: 2024-12-12
# URL: https://www.youtube.com/watch?v=OvS7isQnx6o
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 32
# Quality Score: 80/100
# Title: Desert landscape - loose watercolor style...
# Channel: Kristin Van Leuven
# Published: 2025-07-01
# URL: https://www.youtube.com/watch?v=lNW84wF-__M
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 33
# Quality Score: 80/100
# Title: Unlocking Creativity  Color Palette Challenge and Art Prompt Experiment...
# Channel: Denise Love
# Published: 2023-07-07
# URL: https://www.youtube.com/watch?v=Av5FI5wRmhg
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 34
# Quality Score: 80/100
# Title: Painting Abstract Landscapes: Learning from Diebenkorn / Art with Adele...
# Channel: Adele Sypesteyn - Abstract Art Teacher
# Published: 2019-10-19
# URL: https://www.youtube.com/watch?v=NZo_U4tMRPM
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 35
# Quality Score: 80/100
# Title: How to Develop Creative Habits to Create Business Success(with Srinivas Rao)...
# Channel: Credibility Marketing
# Published: 2021-09-22
# URL: https://www.youtube.com/watch?v=fCw3QBNdaa8
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 36
# Quality Score: 80/100
# Title: How to Talk About Your Art with Greater IMPACT: The Advice of Sergio Gomez...
# Channel: Sergio Gomez - Art, Business & Marketing
# Published: 2019-05-15
# URL: https://www.youtube.com/watch?v=GP1QzKX3SZM
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 37
# Quality Score: 80/100
# Title: Jackson Pollock Part One: The Myth of the Modern Artist...
# Channel: Great Art Explained
# Published: 2025-06-13
# URL: https://www.youtube.com/watch?v=0sQ_cfZ8q9k
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 38
# Quality Score: 80/100
# Title: EP.26 : The Art of Gathering Inspiration...
# Channel: Bonnie Christine
# Published: 2023-02-02
# URL: https://www.youtube.com/watch?v=DtaWjkW-JSQ
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 39
# Quality Score: 80/100
# Title: Jackson Pollock Part One: The Myth of the Modern Artist...
# Channel: Great Art Explained
# Published: 2025-06-13
# URL: https://www.youtube.com/watch?v=0sQ_cfZ8q9k
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 40
# Quality Score: 80/100
# Title: How to Draw the BEST Hyper Realistic Eye | Easy Step-by-Step For All Artists...
# Channel: Zachary Wyland
# Published: 2024-07-05
# URL: https://www.youtube.com/watch?v=Pfbh6UqkUN0
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 41
# Quality Score: 80/100
# Title: OCEAN DOOR surreal drawing tutorial - Procreate made easy...
# Channel: James Julier
# Published: 2023-08-27
# URL: https://www.youtube.com/watch?v=MbJJPe3R4VY
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 42
# Quality Score: 80/100
# Title: 4 Dynamic Salsa Fusion Steps + Practice Routine...
# Channel: Dance Doctor
# Published: 2021-01-26
# URL: https://www.youtube.com/watch?v=gDU8bF42SU0
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 43
# Quality Score: 80/100
# Title: Painting Abstract Landscapes: Learning from Diebenkorn / Art with Adele...
# Channel: Adele Sypesteyn - Abstract Art Teacher
# Published: 2019-10-19
# URL: https://www.youtube.com/watch?v=NZo_U4tMRPM
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 44
# Quality Score: 80/100
# Title: Jackson Pollock Part One: The Myth of the Modern Artist...
# Channel: Great Art Explained
# Published: 2025-06-13
# URL: https://www.youtube.com/watch?v=0sQ_cfZ8q9k
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 45
# Quality Score: 80/100
# Title: Practicing a Routine | Drawing for Tattooers with James Wisdom Ep #12...
# Channel: Reinventing the Tattoo
# Published: 2022-08-09
# URL: https://www.youtube.com/watch?v=CrFN_5BVVnY
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 46
# Quality Score: 80/100
# Title: The Art of Practicing and Developing Your Own Practice Routine with Natalie Helm...
# Channel: Sarasota Orchestra
# Published: 2020-07-20
# URL: https://www.youtube.com/watch?v=qfUa5KtjJiM
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 47
# Quality Score: 80/100
# Title: How I Practice Drawing Caricatures (My Daily Routine!)...
# Channel: RowserWorld
# Published: 2025-11-19
# URL: https://www.youtube.com/watch?v=v0FgNV8IeAc
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 48
# Quality Score: 80/100
# Title: Regular yoga practice, 50 min. routine workout with Art of learning institute....
# Channel: Art of Learning Institute
# Published: 2020-07-17
# URL: https://www.youtube.com/watch?v=p9hleMdJDlg
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 49
# Quality Score: 80/100
# Title: 1 Hour Guitar Technique Workout - My Real Practice Routine...
# Channel: The Art of Classical Guitar
# Published: 2025-05-04
# URL: https://www.youtube.com/watch?v=ZnS8eD-hiWE
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 50
# Quality Score: 80/100
# Title: 501 - How To Create Gentle Habits with Sophie Yanow...
# Channel: Creative Pep Talk
# Published: 2025-04-17
# URL: https://www.youtube.com/watch?v=3oLAsY4pMSc
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 51
# Quality Score: 80/100
# Title: Good Habits Maximize Creativity, with Emily Leonard...
# Channel: Savvy Painter
# Published: 2018-04-13
# URL: https://www.youtube.com/watch?v=1CZ_p4aWLYc
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 52
# Quality Score: 80/100
# Title: Film Photography For Beginners | How To Use A 35mm Camera...
# Channel: Jessica Whitaker
# Published: 2019-04-11
# URL: https://www.youtube.com/watch?v=kFimMHbguCM
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 53
# Quality Score: 80/100
# Title: I Drew for 11,770 Hours... Here&#39;s What I Learned...
# Channel: oridays
# Published: 2024-08-29
# URL: https://www.youtube.com/watch?v=s9FmIhMGYjg
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 54
# Quality Score: 80/100
# Title: Wabi Sabi Interior Design Style: Decorating Ideas for Small Space...
# Channel: Sweet Magnoliaa Extended Experience
# Published: 2024-07-24
# URL: https://www.youtube.com/watch?v=--w1liD1eo8
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 55
# Quality Score: 80/100
# Title: Wabi Sabi Art | Japanese Listening Practice...
# Channel: Speak Japanese Naturally
# Published: 2025-04-27
# URL: https://www.youtube.com/watch?v=gN7KgA7WqLY
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 56
# Quality Score: 80/100
# Title: BOOST Your Drawing Skills with These Daily Habits!...
# Channel: Draw Sessions
# Published: 2024-10-18
# URL: https://www.youtube.com/watch?v=Jz4siuK9I7s
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 57
# Quality Score: 80/100
# Title: Learn How To Draw Pt 1: Lines, Lines, Lines...
# Channel: The Pencil Room Online
# Published: 2023-01-21
# URL: https://www.youtube.com/watch?v=ing1x95WZ_I
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 58
# Quality Score: 80/100
# Title: How To Sketch ANYTHING! | Urban Sketching Objects For Beginners...
# Channel: Sketching Scottie
# Published: 2024-11-15
# URL: https://www.youtube.com/watch?v=SDQEaJY291A
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 59
# Quality Score: 80/100
# Title: (Non Nude) Daily Life Drawing Session Figure Reference Images #1 in Ultra HD 4K...
# Channel: New Masters Academy
# Published: 2015-01-03
# URL: https://www.youtube.com/watch?v=mNNSwITdPIM
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 60
# Quality Score: 80/100
# Title: Daily Life Drawing Session #8 (Free Timed Figure Model Reference)...
# Channel: New Masters Academy
# Published: 2014-09-24
# URL: https://www.youtube.com/watch?v=Jy1rwangC3k
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 61
# Quality Score: 80/100
# Title: Wabi-Sabi Bedroom Makeover With Custom Ikea Pax Wardrobes...
# Channel: Alexandra Gater
# Published: 2022-11-12
# URL: https://www.youtube.com/watch?v=kQpgyUwUfFw
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 62
# Quality Score: 80/100
# Title: How to Add Mindful Meditative Drawing into Your Daily Practice...
# Channel: Peggy Dean
# Published: 2021-07-28
# URL: https://www.youtube.com/watch?v=l7N2P8aCvg0
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 63
# Quality Score: 80/100
# Title: Daily Drawing - My Tips For Developing a Daily Sketchbook Habit...
# Channel: Sonia Brittain
# Published: 2023-12-14
# URL: https://www.youtube.com/watch?v=IseP7pqPRnA
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 64
# Quality Score: 80/100
# Title: Minimalist Landscape Painting in PROCREATE - Full Tutorial...
# Channel: Tatyworks
# Published: 2022-02-18
# URL: https://www.youtube.com/watch?v=H09NKFSBGIQ
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 65
# Quality Score: 80/100
# Title: Minimalist Plant Painting Tutorial Using Acrylics / Beginner-Friendly...
# Channel: Cheryl Navarro
# Published: 2021-12-05
# URL: https://www.youtube.com/watch?v=EsBW3tYfjZI
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 66
# Quality Score: 80/100
# Title: Mandala ASMR | Relaxing Meditative Drawing &amp; Calming Music...
# Channel: Blissful Coloring World
# Published: 2025-06-12
# URL: https://www.youtube.com/watch?v=gtbECPvSVFc
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 67
# Quality Score: 80/100
# Title: Soothing Mandala ASMR with Meditative Music (Ep. 91)...
# Channel: Blissful Coloring World
# Published: 2025-05-11
# URL: https://www.youtube.com/watch?v=G-xH0__heLg
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 68
# Quality Score: 80/100
# Title: #NeuroGraphic Art: Guided Meditative Drawing - Easy Transition From 2020 to 2021...
# Channel: Alina Smolyansky
# Published: 2021-01-01
# URL: https://www.youtube.com/watch?v=KX4F757U6Jo
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 69
# Quality Score: 80/100
# Title: Art Supplies Organization! Tips to Declutter Your Art Studio...
# Channel: Jess Karp
# Published: 2022-03-12
# URL: https://www.youtube.com/watch?v=ljz_dTsm-VE
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 70
# Quality Score: 80/100
# Title: HOW Daily Sketching Habit Can IMPROVE Your Drawing Skills...
# Channel: ZonVas
# Published: 2025-01-02
# URL: https://www.youtube.com/watch?v=jVtMj6tiFoI
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 71
# Quality Score: 80/100
# Title: 2 Awesome ways to draw Japanese tattoo backgrounds! (Waves and clouds)...
# Channel: Dagget Designs
# Published: 2021-02-18
# URL: https://www.youtube.com/watch?v=8DW4vBQ4uUY
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 72
# Quality Score: 80/100
# Title: Watercolor Tutorial with Yoichi Nishikawa...
# Channel: The Academy
# Published: 2021-07-20
# URL: https://www.youtube.com/watch?v=qH2q9ZJMaAU
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 73
# Quality Score: 80/100
# Title: The ultimate WATERCOLOUR TUTORIAL | For beginners | Drawlikeasir...
# Channel: Draw like a Sir
# Published: 2021-10-24
# URL: https://www.youtube.com/watch?v=C8iKj4pfqAA
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 74
# Quality Score: 80/100
# Title: Easy Minimalist Art: Gold Leaf &amp; Fabric Tutorial...
# Channel: Dzenovagis Art
# Published: 2024-11-20
# URL: https://www.youtube.com/watch?v=dMH7Das0HKk
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 75
# Quality Score: 80/100
# Title: Acrylic April Day 25: Minimalist Abstract Face | Beginner Acrylic Tutorial...
# Channel: theartsherpa
# Published: 2023-04-25
# URL: https://www.youtube.com/watch?v=4Y0eVN34D5M
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 76
# Quality Score: 80/100
# Title: Impressionism for Beginners | Oil Painting Tutorial...
# Channel: Painting with Samir
# Published: 2020-08-30
# URL: https://www.youtube.com/watch?v=Q4BSqW1BAFs
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 77
# Quality Score: 80/100
# Title: Introduction to Sumi-e Basic Strokes.MOV...
# Channel: mrlundgren1
# Published: 2012-01-06
# URL: https://www.youtube.com/watch?v=z_EoHOUIkNA
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 78
# Quality Score: 80/100
# Title: Easy Cherry Blossom Trees Tutorial | Watercolor for Beginners...
# Channel: Kerrilyn Cheah
# Published: 2021-04-08
# URL: https://www.youtube.com/watch?v=HSEdWPOygtg
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 79
# Quality Score: 80/100
# Title: How to Paint a Landscape in the Style of a Japanese Print in Line and Wash...
# Channel: Paul Clark
# Published: 2023-01-04
# URL: https://www.youtube.com/watch?v=GNp3gsGsUkk
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 80
# Quality Score: 80/100
# Title: How to Paint Like Impressionist | Oil painting Tutorial...
# Channel: Painting with Samir
# Published: 2020-10-21
# URL: https://www.youtube.com/watch?v=FECqgU5vrCw
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 81
# Quality Score: 80/100
# Title: Easy Impressionist Floral Vase #2 Acrylic Painting Tutorial LIVE...
# Channel: Angela Anderson
# Published: 2017-07-08
# URL: https://www.youtube.com/watch?v=1Xs96GzVrDo
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 82
# Quality Score: 80/100
# Title: Paint like an IMPRESSIONIST on your iPad - Step by Step Procreate Tutorial...
# Channel: Art with Flo
# Published: 2023-09-15
# URL: https://www.youtube.com/watch?v=izRCb6LYP-0
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 83
# Quality Score: 80/100
# Title: Impressionist Flower Garden Acrylic Painting Tutorial LIVE...
# Channel: Angela Anderson
# Published: 2018-02-17
# URL: https://www.youtube.com/watch?v=sH52WZY1hTA
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 84
# Quality Score: 80/100
# Title: Monet Waterlilies Bridge (Part 1) Impressionist Acrylic Painting Tutorial LIVE...
# Channel: Angela Anderson
# Published: 2016-10-22
# URL: https://www.youtube.com/watch?v=zdDJkbjMqOc
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 85
# Quality Score: 80/100
# Title: Zentangle Inspired Meditative Drawing || Zen Doodle...
# Channel: LeaSwork
# Published: 2021-10-16
# URL: https://www.youtube.com/watch?v=Bc-QJjfR85g
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 86
# Quality Score: 80/100
# Title: Meditative Sketchnote Workshop with Ben Norris &amp; Mike Rohde...
# Channel: Mike Rohde
# Published: 2021-11-18
# URL: https://www.youtube.com/watch?v=F9gUNLwOfOk
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 87
# Quality Score: 80/100
# Title: Good Habits Maximize Creativity, with Emily Leonard...
# Channel: Savvy Painter
# Published: 2017-06-06
# URL: https://www.youtube.com/watch?v=IGFJ7TZtIHc
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 88
# Quality Score: 80/100
# Title: 5  Simple but Weird HABITS to be more creative with your HOME Decor...
# Channel: Debi's Design Diary
# Published: 2025-02-23
# URL: https://www.youtube.com/watch?v=nVLWpilw1fM
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 89
# Quality Score: 80/100
# Title: How to Make Etegami Picture Letters with Sumi Ink and Watercolor DEMO...
# Channel: Create with Karen Elaine
# Published: 2021-12-02
# URL: https://www.youtube.com/watch?v=jccdbC2oAlw
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 90
# Quality Score: 80/100
# Title: Dry-mount a Sumi-e or Chinese Painting with Iron-on Silk Margins...
# Channel: BlueHeronArts - Henry Li
# Published: 2016-01-03
# URL: https://www.youtube.com/watch?v=Jvw74_OKRx8
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 91
# Quality Score: 80/100
# Title: Impressionist Poppies Step by Step Acrylic Painting on Canvas for Beginners...
# Channel: Painting with Jane
# Published: 2016-05-24
# URL: https://www.youtube.com/watch?v=aLjS98OhFyQ
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 92
# Quality Score: 80/100
# Title: Sumi e watercolor painting using Painter...
# Channel: PainterTutorials
# Published: 2021-06-22
# URL: https://www.youtube.com/watch?v=1W9ZlQyeBTU
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 93
# Quality Score: 80/100
# Title: How to Paint Impressionistic Pink Poppies in Watercolor / Great for Beginners...
# Channel: Monet Cafe' with Artist Susan Jenkins
# Published: 2021-06-03
# URL: https://www.youtube.com/watch?v=SxxSDZjbtVc
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 94
# Quality Score: 80/100
# Title: Scandinavian Folk Art Drawing with Procreate - Stay Home and Draw...
# Channel: Bardot Brush
# Published: 2020-04-24
# URL: https://www.youtube.com/watch?v=AOuYbW7rGvc
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 95
# Quality Score: 80/100
# Title: Crochet Scandinavian Snowflake Afghan Pattern | EASY | The Crochet Crowd...
# Channel: The Crochet Crowd
# Published: 2015-12-31
# URL: https://www.youtube.com/watch?v=4YeQYiBttyk
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 96
# Quality Score: 80/100
# Title: Easy Acrylic Painting Tutorial -  Impressionist Trees - Free Lesson...
# Channel: Angela Anderson
# Published: 2015-05-09
# URL: https://www.youtube.com/watch?v=FyQ832N3sVc
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 97
# Quality Score: 80/100
# Title: 9 Easy Zentangle Patterns for Beginners - Organic &amp; Botanical...
# Channel: Emily Suess Zentangles
# Published: 2020-12-09
# URL: https://www.youtube.com/watch?v=DTa_eWXx0FU
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 98
# Quality Score: 80/100
# Title: Zentangle for Beginners - Step by Step Tutorial for How to Draw a Zentangle...
# Channel: Mr. New's Art Class
# Published: 2016-10-08
# URL: https://www.youtube.com/watch?v=tXaLQzyjA2U
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 99
# Quality Score: 80/100
# Title: Peaceful Mandala Journey | ASMR + Meditative Music...
# Channel: Blissful Coloring World
# Published: 2025-06-09
# URL: https://www.youtube.com/watch?v=xyXB5f9SBek
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
# Rank: 100
# Quality Score: 80/100
# Title: Art Galleries Explained: Everything You Need To Know (Complete Webinar)...
# Channel: Contemporary Art Issue
# Published: 2022-04-10
# URL: https://www.youtube.com/watch?v=D2SxsskPPvw
# Score Breakdown: +10 good length | +10 decent desc; +10 educational | +10 established channel | Invalid date | +15 consistent
# ----------------------------------------------------------------------------------------------------
#
#
# Results saved to: video_analysis_results.csv
#
# ====================================================================================================
# QUALITY DISTRIBUTION
# ====================================================================================================
# Average Score: 65.1
# Median Score: 65.0
# Highest Score: 80.0
# Lowest Score: 35.0
#
# Total Videos Analyzed: 3780
