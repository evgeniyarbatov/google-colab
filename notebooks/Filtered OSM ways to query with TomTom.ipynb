# %%
import pandas as pd

ways_df = pd.read_csv('/content/ways.csv')

ways_below_30k = ways_df[ways_df['distance'] < 30000]

num_ways_below_30k = len(ways_below_30k)

print(f"The number of ways with a distance below 30000 is: {num_ways_below_30k}")
# Out:
# The number of ways with a distance below 30000 is: 6815

# %%
ways_df_cleaned = ways_df.dropna(subset=['min_distance'])
ways_df_cleaned['min_distance_km'] = (ways_df_cleaned['min_distance'] / 1000).round(1)
way_id_by_min_distance_km = ways_df_cleaned.groupby('min_distance_km')['way_id'].count()
with pd.option_context('display.max_rows', None):
    display(way_id_by_min_distance_km)
# Out:
# /tmp/ipython-input-2006365389.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ways_df_cleaned['min_distance_km'] = (ways_df_cleaned['min_distance'] / 1000).round(1)
# min_distance_km
# 0.0     3842
# 0.1     2142
# 0.2     1113
# 0.3      644
# 0.4      449
# 0.5      291
# 0.6      233
# 0.7      181
# 0.8      139
# 0.9       96
# 1.0      100
# 1.1       84
# 1.2       65
# 1.3       56
# 1.4       61
# 1.5       33
# 1.6       37
# 1.7       35
# 1.8       25
# 1.9       19
# 2.0       20
# 2.1       22
# 2.2       13
# 2.3       13
# 2.4       19
# 2.5       10
# 2.6       11
# 2.7        8
# 2.8        5
# 2.9        6
# 3.0        3
# 3.1        7
# 3.2        3
# 3.3        3
# 3.4        5
# 3.5        4
# 3.6        4
# 3.7        5
# 3.8        4
# 3.9        4
# 4.0        1
# 4.1        4
# 4.2        3
# 4.3        2
# 4.4        2
# 4.5        3
# 4.6        2
# 4.7        1
# 4.8        1
# 4.9        1
# 5.1        2
# 5.2        1
# 5.3        3
# 5.4        3
# 5.5        1
# 5.6        1
# 5.7        2
# 5.8        1
# 5.9        2
# 6.1        1
# 6.4        1
# 6.6        1
# 6.7        1
# 7.1        2
# 7.2        1
# 7.3        1
# 7.4        1
# 7.9        1
# 8.0        1
# 8.1        1
# 8.2        1
# 8.5        1
# 8.8        1
# 9.0        1
# 10.7       1
# 10.8       1
# 12.4       1
# 15.5       1
# 16.2       1
# 17.2       1
# 19.9       1
# 20.1       1
# Name: way_id, dtype: int64

# %%
ways_filtered = ways_df_cleaned[(ways_df_cleaned['min_distance_km'] > 0.6) & (ways_df_cleaned['distance'] < 30000)]
num_ways_filtered = len(ways_filtered)

print(f"The number of ways with min_distance_km greater than 0.1 and distance below 30000 is: {num_ways_filtered}")
# Out:
# The number of ways with min_distance_km greater than 0.1 and distance below 30000 is: 489

# %%
import folium

# Get the center of the filtered data
center_lat = ways_filtered['lat'].mean()
center_lon = ways_filtered['lon'].mean()

# Create a map centered around the data
m = folium.Map(location=[center_lat, center_lon], zoom_start=12)

# Add markers for each way in the filtered data
for index, row in ways_filtered.iterrows():
    folium.Marker([row['lat'], row['lon']]).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bc27f780aad413b7b77fe450c428e6d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bc27f780aad413b7b77fe450c428e6d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4bc27f780aad413b7b77fe450c428e6d = L.map(
#                 &quot;map_4bc27f780aad413b7b77fe450c428e6d&quot;,
#                 {
#                     center: [20.99525449891915, 105.77919613525789],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cba6385912cc021e0cce59c562624713 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cba6385912cc021e0cce59c562624713.addTo(map_4bc27f780aad413b7b77fe450c428e6d);
#
#
#             var marker_e99dbac318f69a2db16a5b9c26d71ea7 = L.marker(
#                 [21.03929674998876, 105.84715580031852],
#                 {
# }
#             ).addTo(map_4bc27f780aad413b7b77fe450c428e6d);
#
#
#             var marker_e720afc38212030d530b759a7343564b = L.marker(
#                 [21.02672118158632, 105.8366818159284],
#                 {
# }
#             ).addTo(map_4bc27f780aad413b7b77fe450c428e6d);
#
#
#             var marker_9ee5f0afb45ca676bfd3734becb457a3 = L.marker(
#                 [21.01886809666385, 105.8431001818448],
#                 {
# }
#             ).addTo(map_4bc27f780aad413b7b77fe450c428e6d);
#
#
#             var marker_f6c8f27b02ab7f8627c8e34c0f683bfd = L.marker(
#                 [21.02518040622405, 105.85418529767816],
#                 {
# }
#             ).addTo(map_4bc27f780aad413b7b77fe450c428e6d);
#
#
#             var marker_ffce3638108e90ee84fb38bfc5a224ff = L.marker(
#                 [20.965539016455764, 105.84341794596553],
#                 {
# }
#             ).addTo(map_4bc27f780aad413b7b77fe450c428e6d);
#
#
#             var marker_eff4605c8155298d8761296a806f850c = L.marker(
#                 [21.019980514033858, 105.86161101623316],
#                 {
# }
#             ).addTo(map_4bc27f780aad413b7b77fe450c428e6d);
#
#
#             var marker_f6ca8f0a1af3390ce2ee11bedc5bfdc8 = L.marker(
#                 [21.02754158006621, 105.84398208631625],
#                 {
# }
#             ).addTo(map_4bc27f780aad413b7b77fe450c428e6d);
#
#
#             var marker_e9547f036396695e93b5c780ee3092d1 = L.marker(
#                 [21.00724137181661, 105.8608516032604],
#                 {
# }
#             ).addTo(map_4bc27f780aad413b7b77fe450c428e6d);
#
#
#             var marker_0422dffc6017f733ed14d608e582a0a6 = L.marker(
#                 [20.995144576616948, 105.85625987168667],
#                 {
# }
#             ).addTo(map_4bc27f780aad413b7b77fe450c428e6d);
#
#
#             var marker_0fffc612c41e87d015af3e26a3649f81 = L.marker(
#                 [20.99949444727473, 105.82869993988037],
#                 {
# }
#             ).addTo(map_4bc27f780aad413b7b77fe450c428e6d);
#
#
#             var marker_5ffc91b37337737ef8f49be1e914962f = L.marker(
#                 [21.03089825309412, 105.82694702177996],
#                 {
# }
#             ).addTo(map_4bc27f780aad413b7b77fe450c428e6d);
#
#
#             var marker_e2644155218bda630b9797f332d1e136 = L.marker(
#                 [21.033112810859546, 105.8344136118006],
#                 {
# }
#             ).addTo(map_4bc27f780aad413b7b77fe450c428e6d);
#
#
#             var marker_04be4a3ee4a2c62ea85f538d64380532 = L.marker(
#                 [21.041939373573555, 105.84010424638788],
#                 {
# }
#             ).addTo(map_4bc27f780aad413b7b77fe450c428e6d);
#
#
#             var marker_035e521116bf82ec400c4f46275d9668 = L.marker(
#                 [21.000206030058617, 105.8353834015134],
#                 {
# }
#             ).addTo(map_4bc27f780aad413b7b77fe450c428e6d);
#
#
#             var marker_f2373ad03dde97f44a9a255f4ae59730 = L.marker(
#                 [21.01130385, 105.83074195],
#                 {
# }
#             ).addTo(map_4bc27f780aad413b7b77fe450c428e6d);
#
#
#             var marker_ccb8e40b1bd17785a316d865d99778d0 = L.marker(
#                 [21.00920182331513, 105.75031416818196],
#                 {
# }
#             ).addTo(map_4bc27f780aad413b7b77fe450c428e6d);
#
#
#             var marker_cb89221c25a8ad92729608ea23318046 = L.marker(
#                 [21.039855989384623, 105.81291611088146],
#                 {
# }
#             ).addTo(map_4bc27f780aad413b7b77fe450c428e6d);
#
#
#             var marker_dc12c21abec3d0a8e0328637cea137d4 = L.marker(
#                 [21.02678348908483, 105.81780951493928],
#                 {
# }
#             ).addTo(
