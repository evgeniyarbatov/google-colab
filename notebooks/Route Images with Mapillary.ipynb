# %%
# !pip install mapillary
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.2/829.2 kB 12.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 53.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 470.9/470.9 kB 30.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.1/41.1 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 4.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.8/69.8 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.7/53.7 kB 4.2 MB/s eta 0:00:00
# ...

# %%
import mapillary.interface as mly
import requests
import json
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1faff3a56b56> in <cell line: 1>()
# ----> 1 import mapillary.interface as mly
#       2 import requests
#       3 import json
#
# ModuleNotFoundError: No module named 'mapillary'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
mly.set_access_token('MLY|7684958804945842|e726f0f4fa1b09017027548eb37bae1c')
# Out:
# {'token': 'SUCCESS'}

# %%
data = mly.get_image_close_to(longitude=105.867470, latitude=20.993494, radius=5, image_type="pano").to_dict()
# Out:
# Requesting GET to https://tiles.mapillary.com/maps/vtp/mly1_public/2/14/13010/7214/?access_token=MLY%7C7684958804945842%7Ce726f0f4fa1b09017027548eb37bae1c
# INFO:mapillary.utils.client:Requesting GET to https://tiles.mapillary.com/maps/vtp/mly1_public/2/14/13010/7214/?access_token=MLY%7C7684958804945842%7Ce726f0f4fa1b09017027548eb37bae1c
# Response 200 OK received in 386ms
# INFO:mapillary.utils.client:Response 200 OK received in 386ms
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [105.86751401424408, 20.99347635652083]},
#    'properties': {'captured_at': 1695637554284,
#     'compass_angle': 205.02366655464698,
#     'creator_id': 815559760355906,
#     'id': 864777645160611,
#     'is_pano': True,
#     'organization_id': 724244826106545,
#     'sequence_id': 'JzRcgkQ5PptY4TViOUmvCq'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
# ...
