# %%
# %%capture

# !pip install gdown

# %%
# %%capture

import gdown

URL = 'https://drive.google.com/file/d/1MkjFgglvhCRHqlcjMBVW5pvebQCbsGmu/view?usp=sharing'
gdown.download(URL, 'original.jpg', quiet=True, fuzzy=True)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def show_image(path):
    fig, ax = plt.subplots(figsize=(20, 10))
    img = mpimg.imread(path)
    ax.imshow(img)
    ax.axis('off')
    plt.tight_layout()
    plt.show()

show_image('original.jpg')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from PIL import Image
from PIL.ExifTags import TAGS

def get_exif(image_path):
    with Image.open(image_path) as img:
        exif_data = img._getexif()
        if not exif_data:
            return None

        exif = {
            TAGS.get(tag, tag): value
            for tag, value in exif_data.items()
            if tag in TAGS
        }

        return exif

get_exif('original.jpg')
# Out:
# {'GPSInfo': {0: b'\x02\x02\x00\x00',
#   1: 'N',
#   2: (20.0, 59.0, 37.06),
#   3: 'E',
#   4: (105.0, 52.0, 9.46),
#   5: b'\x00',
#   6: 25.6,
#   7: (10.0, 36.0, 49.0),
#   16: 'M',
#   17: 10.0,
#   29: '2024:12:24'},
#  'ResolutionUnit': 2,
#  'ExifOffset': 219,
#  'Make': 'Google',
#  'Model': 'Pixel 6a',
#  'Software': 'HDR+ 1.0.702121622zd',
#  'Orientation': 1,
#  'DateTime': '2024:12:24 17:37:34',
#  'YCbCrPositioning': 1,
#  'XResolution': 72.0,
#  'YResolution': 72.0,
#  'ExifVersion': b'0232',
#  'ComponentsConfiguration': b'\x01\x02\x03\x00',
#  'ShutterSpeedValue': 5.06,
#  'DateTimeOriginal': '2024:12:24 17:37:34',
#  'DateTimeDigitized': '2024:12:24 17:37:34',
#  'ApertureValue': 2.28,
#  'BrightnessValue': 0.1,
#  'ExposureBiasValue': 0.0,
#  'MaxApertureValue': 2.28,
#  'SubjectDistance': 4294967295.0,
#  'MeteringMode': 2,
#  'Flash': 16,
#  'FocalLength': 2.35,
#  'ColorSpace': 1,
#  'ExifImageWidth': 4032,
#  'SceneCaptureType': 0,
#  'OffsetTime': '+07:00',
#  'OffsetTimeOriginal': '+07:00',
#  'OffsetTimeDigitized': '+07:00',
#  'SubsecTime': '281',
#  'SubsecTimeOriginal': '281',
#  'SubsecTimeDigitized': '281',
#  'ExifImageHeight': 3024,
#  'SensingMethod': 2,
#  'ExposureTime': 0.029991,
#  'ExifInteroperabilityOffset': 923,
#  'FNumber': 2.2,
#  'SceneType': b'\x01',
#  'ExposureProgram': 2,
#  'CustomRendered': 1,
#  'ISOSpeedRatings': 472,
#  'ExposureMode': 0,
#  'FlashPixVersion': b'0100',
#  'WhiteBalance': 0,
#  'LensMake': 'Google',
#  'LensModel': 'Pixel 6a back camera 2.35mm f/2.2',
#  'DigitalZoomRatio': 0.0,
#  'FocalLengthIn35mmFilm': 16,
#  'Contrast': 0,
#  'Saturation': 0,
#  'Sharpness': 0,
#  'SubjectDistanceRange': 3,
#  'CompositeImage': 3}

# %%
# %%capture

import gdown

URL = 'https://drive.google.com/file/d/1MlPIbsOTVWcE10N7GcT7oCZajtWL_kBq/view?usp=sharing'
gdown.download(URL, 'original.jpg', quiet=True, fuzzy=True)

# %%
get_exif('original.jpg')
# Out:
# {'GPSInfo': {0: b'\x02\x02\x00\x00',
#   1: 'N',
#   2: (20.0, 59.0, 37.09),
#   3: 'E',
#   4: (105.0, 52.0, 9.5),
#   5: b'\x00',
#   6: 25.6,
#   7: (11.0, 15.0, 38.0),
#   16: 'M',
#   17: 347.0,
#   29: '2024:12:24'},
#  'ResolutionUnit': 2,
#  'ExifOffset': 219,
#  'Make': 'Google',
#  'Model': 'Pixel 6a',
#  'Software': 'HDR+ 1.0.702121622zd',
#  'Orientation': 1,
#  'DateTime': '2024:12:24 18:15:42',
#  'YCbCrPositioning': 1,
#  'XResolution': 72.0,
#  'YResolution': 72.0,
#  'ExifVersion': b'0232',
#  'ComponentsConfiguration': b'\x01\x02\x03\x00',
#  'ShutterSpeedValue': 8.32,
#  'DateTimeOriginal': '2024:12:24 18:15:42',
#  'DateTimeDigitized': '2024:12:24 18:15:42',
#  'ApertureValue': 1.58,
#  'BrightnessValue': 5.67,
#  'ExposureBiasValue': 0.0,
#  'MaxApertureValue': 1.58,
#  'SubjectDistance': 0.127,
#  'MeteringMode': 2,
#  'Flash': 16,
#  'FocalLength': 4.38,
#  'ColorSpace': 1,
#  'ExifImageWidth': 3024,
#  'SceneCaptureType': 0,
#  'OffsetTime': '+07:00',
#  'OffsetTimeOriginal': '+07:00',
#  'OffsetTimeDigitized': '+07:00',
#  'SubsecTime': '478',
#  'SubsecTimeOriginal': '478',
#  'SubsecTimeDigitized': '478',
#  'ExifImageHeight': 4032,
#  'SensingMethod': 2,
#  'ExposureTime': 0.003121,
#  'ExifInteroperabilityOffset': 924,
#  'FNumber': 1.73,
#  'SceneType': b'\x01',
#  'ExposureProgram': 2,
#  'CustomRendered': 1,
#  'ISOSpeedRatings': 59,
#  'ExposureMode': 0,
#  'FlashPixVersion': b'0100',
#  'WhiteBalance': 0,
#  'LensMake': 'Google',
#  'LensModel': 'Pixel 6a back camera 4.38mm f/1.73',
#  'DigitalZoomRatio': 0.0,
#  'FocalLengthIn35mmFilm': 27,
#  'Contrast': 0,
#  'Saturation': 0,
#  'Sharpness': 0,
#  'SubjectDistanceRange': 1,
#  'CompositeImage': 3}

# %%
# %%capture

import gdown

URL = 'https://drive.google.com/file/d/1MmDnZqOx660ubZysb0KsHZNJ8ddEPhPR/view?usp=sharing'
gdown.download(URL, 'original.jpg', quiet=True, fuzzy=True)

# %%
get_exif('original.jpg')
# Out:
# {'GPSInfo': {0: b'\x02\x02\x00\x00',
#   1: 'N',
#   2: (20.0, 59.0, 37.14),
#   3: 'E',
#   4: (105.0, 52.0, 9.69),
#   5: b'\x00',
#   6: 25.4,
#   7: (11.0, 17.0, 43.0),
#   16: 'M',
#   17: 2.0,
#   29: '2024:12:24'},
#  'ResolutionUnit': 2,
#  'ExifOffset': 219,
#  'Make': 'Google',
#  'Model': 'Pixel 6a',
#  'Software': 'HDR+ 1.0.702121622zd',
#  'Orientation': 1,
#  'DateTime': '2024:12:24 18:17:46',
#  'YCbCrPositioning': 1,
#  'XResolution': 72.0,
#  'YResolution': 72.0,
#  'ExifVersion': b'0232',
#  'ComponentsConfiguration': b'\x01\x02\x03\x00',
#  'ShutterSpeedValue': 6.64,
#  'DateTimeOriginal': '2024:12:24 18:17:46',
#  'DateTimeDigitized': '2024:12:24 18:17:46',
#  'ApertureValue': 1.58,
#  'BrightnessValue': 3.33,
#  'ExposureBiasValue': 0.0,
#  'MaxApertureValue': 1.58,
#  'SubjectDistance': 0.112,
#  'MeteringMode': 2,
#  'Flash': 16,
#  'FocalLength': 4.38,
#  'ColorSpace': 1,
#  'ExifImageWidth': 3024,
#  'SceneCaptureType': 0,
#  'OffsetTime': '+07:00',
#  'OffsetTimeOriginal': '+07:00',
#  'OffsetTimeDigitized': '+07:00',
#  'SubsecTime': '846',
#  'SubsecTimeOriginal': '846',
#  'SubsecTimeDigitized': '846',
#  'ExifImageHeight': 4032,
#  'SensingMethod': 2,
#  'ExposureTime': 0.010006,
#  'ExifInteroperabilityOffset': 924,
#  'FNumber': 1.73,
#  'SceneType': b'\x01',
#  'ExposureProgram': 2,
#  'CustomRendered': 1,
#  'ISOSpeedRatings': 93,
#  'ExposureMode': 0,
#  'FlashPixVersion': b'0100',
#  'WhiteBalance': 0,
#  'LensMake': 'Google',
#  'LensModel': 'Pixel 6a back camera 4.38mm f/1.73',
#  'DigitalZoomRatio': 2.0,
#  'FocalLengthIn35mmFilm': 27,
#  'Contrast': 0,
#  'Saturation': 0,
#  'Sharpness': 0,
#  'SubjectDistanceRange': 1,
#  'CompositeImage': 3}
