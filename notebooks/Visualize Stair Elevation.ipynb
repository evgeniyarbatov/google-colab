# %% [markdown]
# # Task
# Create a 3D visualization of the route data from `/content/activity_elevation.csv` using latitude, longitude, and elevation. Generate a detailed static image of the 3D plot.

# %% [markdown]
# ## Load the data
#
# ### Subtask:
# Load the data from the `/content/activity_elevation.csv` file into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Import the pandas library and load the data from the CSV file into a pandas DataFrame.

# %%
import pandas as pd

df = pd.read_csv('/content/activity_elevation.csv')

# %% [markdown]
# ## Inspect the data
#
# ### Subtask:
# Display the first few rows and the columns of the DataFrame to understand its structure and content.

# %% [markdown]
# **Reasoning**:
# Display the first few rows and the column information of the DataFrame to understand its structure and content.

# %%
display(df.head())
df.info()
# Out:
#          lat         lon  elevation
# 0  20.993431  105.869540      38.62
# 1  20.993431  105.869542      38.49
# 2  20.993431  105.869544      38.59
# 3  20.993431  105.869547      38.75
# 4  20.993431  105.869553      39.11
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028 entries, 0 to 1027
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        1028 non-null   float64
#  1   lon        1028 non-null   float64
#  2   elevation  1028 non-null   float64
# dtypes: float64(3)
# memory usage: 24.2 KB

# %% [markdown]
# ## Prepare the data
#
# ### Subtask:
# Extract the relevant columns for latitude, longitude, and elevation, ensuring they are in the correct format for plotting.

# %% [markdown]
# **Reasoning**:
# Select the 'lat', 'lon', and 'elevation' columns from the DataFrame and store them in a new variable.

# %%
route_data = df[['lat', 'lon', 'elevation']]

# %% [markdown]
# ## Create the 3d visualization
#
# ### Subtask:
# Use a suitable plotting library (like Plotly) to create a 3D scatter plot of the route using the latitude, longitude, and elevation data.

# %% [markdown]
# **Reasoning**:
# Create a 3D scatter plot using plotly.express with longitude on the x-axis, latitude on the y-axis, and elevation on the z-axis.

# %%
import plotly.express as px

# Sample the data to reduce the number of points
sampled_route_data = route_data.iloc[::10] # Take every 10th point

fig = px.line_3d(sampled_route_data, x='lon', y='lat', z='elevation', color='elevation')

# %% [markdown]
# ## Customize the visualization
#
# ### Subtask:
# Add details like axis labels, title, and potentially different colors or markers to enhance the visualization.

# %% [markdown]
# **Reasoning**:
# Update the layout of the Plotly figure to add a title and axis labels as per the instructions.

# %%
fig.update_layout(
    title='3D Route Visualization by Elevation',
    scene = dict(
        xaxis_title='',
        yaxis_title='',
        zaxis_title='Elevation',
        xaxis=dict(showgrid=False, backgroundcolor='rgba(0,0,0,0)'),
        yaxis=dict(showgrid=False, backgroundcolor='rgba(0,0,0,0)'),
        zaxis=dict(showgrid=False, backgroundcolor='rgba(0,0,0,0)'),
        # Adjust scene settings to prevent cutting off
        camera=dict(
            up=dict(x=0, y=0, z=1),
            center=dict(x=0, y=0, z=0),
            eye=dict(x=1.25, y=1.25, z=1.25)
        )
    ),
    paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)'
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0ef7bf1a-9cc5-4449-a14a-aa5cd66264e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ef7bf1a-9cc5-4449-a14a-aa5cd66264e4")) {                    Plotly.newPlot(                        "0ef7bf1a-9cc5-4449-a14a-aa5cd66264e4",                        [{"hovertemplate":"elevation=%{z}\u003cbr\u003elon=%{x}\u003cbr\u003elat=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"38.62","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"38.62","scene":"scene","showlegend":true,"x":[105.86953987],"y":[20.99343056],"z":[38.62],"type":"scatter3d"},{"hovertemplate":"elevation=%{z}\u003cbr\u003elon=%{x}\u003cbr\u003elat=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"41.73","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"41.73","scene":"scene","showlegend":true,"x":[105.86954101],"y":[20.99343056],"z":[41.73],"type":"scatter3d"},{"hovertemplate":"elevation=%{z}\u003cbr\u003elon=%{x}\u003cbr\u003elat=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"46.9","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"46.9","scene":"scene","showlegend":true,"x":[105.86956438],"y":[20.99344465],"z":[46.9],"type":"scatter3d"},{"hovertemplate":"elevation=%{z}\u003cbr\u003elon=%{x}\u003cbr\u003elat=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"49.78","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"49.78","scene":"scene","showlegend":true,"x":[105.86956702],"y":[20.99343056],"z":[49.78],"type":"scatter3d"},{"hovertemplate":"elevation=%{z}\u003cbr\u003elon=%{x}\u003cbr\u003elat=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"53.75","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"53.75","scene":"scene","showlegend":true,"x":[105.86955993],"y":[20.99344465],"z":[53.75],"type":"scatter3d"},{"hovertemplate":"elevation=%{z}\u003cbr\u003elon=%{x}\u003cbr\u003elat=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"55.99","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"55.99","scene":"scene","showlegend":true,"x":[105.86955997],"y":[20.99343056],"z":[55.99],"type":"scatter3d"},{"hovertemplate":"elevation=%{z}\u003cbr\u003elon=%{x}\u003cbr\u003elat=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"66.29","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"66.29","scene":"scene","showlegend":true,"x":[105.86954226],"y":[20.99344465],"z":[66.29],"type":"scatter3d"},{"hovertemplate":"elevation=%{z}\u003cbr\u003elon=%{x}\u003cbr\u003elat=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"65.1","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"65.1","scene":"scene","showlegend":true,"x":[105.86955476],"y":[20.99344465],"z":[65.1],"type":"scatter3d"},{"hovertemplate":"elevation=%{z}\u003cbr\u003elon=%{x}\u003cbr\u003elat=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"70.22","line":{"color":"#FF97FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"70.22","scene":"scene","showlegend":true,"x":[105.86956676],"y":[20.99343056],"z":[70.22],"type":"scatter3d"},{"hovertemplate":"elevation=%{z}\u003cbr\u003elon=%{x}\u003cbr\u003elat=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"70.52","line":{"color":"#FECB52","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"70.52","scene":"scene","showlegend":true,"x":[105.86955559],"y":[20.99344465],"z":[70.52],"type":"scatter3d"},{" ...
